# %%
# 3. 哪個觀光遊憩景點遊客假日與非假日人次變化率最高?

import pandas as pd

# 賦予colab拜訪google drive的權限
from google.colab import drive
drive.mount('/content/drive')

# 存取我的雲端硬碟中practice這個資料夾中檔名為Tainan(2).csv.csv的檔案，並轉為Dataframe的形式
df = pd.read_csv('/content/drive/My Drive/practice/Tainan(2).csv.csv')

# # 列印出Dataframe形式的資料
df
# Out:
# Mounted at /content/drive
#          觀光遊憩區別 遊客人次有門票_需購票  遊客人次無門票   遊客人次假日  遊客人次非假日        門票收入 上年同月遊客人數  \
# 0        臺灣鹽博物館           -        -        -        -           -        -
# 1          七股鹽山      19,359    7,532   14,926   11,965    $489,850   13,215
# 2        北門遊客中心         NaN   30,549   15,337   15,212         NaN   14,892
# 3       井仔腳瓦盤鹽田         NaN   33,111   15,531   17,580         NaN   12,983
# 4      柳營尖山埤渡假村       7,771    4,194    5,897    6,068    $211,990    4,336
# 5      烏山頭水庫風景區      22,047    1,829    6,674   17,202    $916,045   16,278
# 6          曾文水庫      16,403    1,739   10,126    8,016    $925,942   12,684
# 7        關子嶺溫泉區         NaN   74,173   43,290   30,883         NaN  165,388
# 8        虎頭埤風景區      15,910   21,707   20,777   16,840    $893,862   26,779
# 9        南元休閒農場       2,429    1,721    2,629    1,521    $594,945      524
# 10        走馬瀨農場      13,425    7,491   12,442    8,474  $2,653,380    2,869
# 11      烏樹林休閒園區         NaN    7,231    5,001    2,230         NaN    1,084
# 12         頑皮世界      21,124    2,321   12,511   10,934  $7,681,858    9,764
# 13       南鯤鯓代天府         NaN  756,000  453,600  302,400         NaN  720,000
# 14        麻豆代天府         NaN  303,750  182,250  121,500         NaN   59,558
# 15     馬沙溝濱海遊憩區         796      NaN      676      120     $93,340      698
# 16    國立臺灣歷史博物館       7,976   36,492   29,403   15,065    $808,450   21,496
# 17        奇美博物館      29,315   10,933   16,635   23,613  $5,363,420   19,123
# 18       臺南市美術館      15,036   15,394   15,396   15,034  $2,070,450   20,064
# 19  臺南山上花園水道博物館      11,880    6,279   11,289    6,870    $776,480   10,142
# 20        臺南孔子廟       7,799    3,900    5,195    6,504    $285,300    2,779
# 21         祀典武廟         NaN   19,359    8,759   10,600         NaN    7,438
# 22          赤崁樓      17,670    9,986   12,513   15,143  $1,201,223   10,626
# 23         大天后宮         NaN   22,125   10,010   12,115         NaN    8,501
# 24         安平小鎮      44,949  271,773  137,318  179,404  $2,662,310   20,592
# 25       南紡購物中心         NaN  513,878  234,870  279,008         NaN      NaN
# 26         新化老街         NaN  134,217   49,380   84,837         NaN      NaN
# 27         鹽水老街         NaN   67,722   24,239   43,483         NaN      NaN
# 28         黃金海岸         NaN   20,905    8,343   12,562         NaN      NaN
# 29      藍晒圖文創園區         NaN  342,941  163,261  179,680         NaN      NaN
#
#                            備註
# 0              門票數(自111年閉館整修)
# 1                         門票數
# 2                       停車數概估
# 3                       停車數概估
# 4                         門票數
# 5                         門票數
# 6                         門票數
# 7                      自動車流監視
# 8                         門票數
# 9                         門票數
# 10                        門票數
# 11                        門票數
# 12                        門票數
# 13                       廟方估計
# 14                       廟方估計
# 15                      人工計數器
# 16                        門票數
# 17                        門票數
# 18                   門票數及人工計數
# 19                   門票數及人工計數
# 20                      人工計數器
# 21                      人工計數器
# 22                        門票數
# 23                      人工計數器
# 24  門票數及電信人數推估(自112年1月更新統計方式)
# 25       電信數據人數推估(自112年1月起統計)
# 26       電信數據人數推估(自112年1月起統計)
# 27       電信數據人數推估(自112年1月起統計)
# 28       電信數據人數推估(自112年1月起統計)
# 29       電信數據人數推估(自112年1月起統計)

# %%
# 將第一行臺灣鹽博物館的資料刪除
df_new = df.iloc[1:, :]

# 將門票收入、遊客人次假日、遊客人次非假日這三列具有千位分隔符號的逗號刪除掉
df_new['門票收入'] = df_new['門票收入'].str.replace(',', '')
df_new['遊客人次假日'] = df_new['遊客人次假日'].str.replace(',', '')
df_new['遊客人次非假日'] = df_new['遊客人次非假日'].str.replace(',', '')

# 將門票收入這一列值中含有的金錢符號刪除掉
df_new['門票收入'] = df_new['門票收入'].str.replace('$', '')

# 將門票收入這一列值中沒有資料(顯示NaN)的值替換為0
df_new.fillna(0, inplace=True)

# 列印出處理好的資料
df_new
# Out:
# <ipython-input-32-e1a3e79b1469>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['門票收入'] = df_new['門票收入'].str.replace(',', '')
# <ipython-input-32-e1a3e79b1469>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客人次假日'] = df_new['遊客人次假日'].str.replace(',', '')
# <ipython-input-32-e1a3e79b1469>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客人次非假日'] = df_new['遊客人次非假日'].str.replace(',', '')
# <ipython-input-32-e1a3e79b1469>:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_new['門票收入'] = df_new['門票收入'].str.replace('$', '')
# <ipython-input-32-e1a3e79b1469>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['門票收入'] = df_new['門票收入'].str.replace('$', '')
# <ipython-input-32-e1a3e79b1469>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.fillna(0, inplace=True)
#          觀光遊憩區別 遊客人次有門票_需購票  遊客人次無門票  遊客人次假日 遊客人次非假日     門票收入 上年同月遊客人數  \
# 1          七股鹽山      19,359    7,532   14926   11965   489850   13,215
# 2        北門遊客中心           0   30,549   15337   15212        0   14,892
# 3       井仔腳瓦盤鹽田           0   33,111   15531   17580        0   12,983
# 4      柳營尖山埤渡假村       7,771    4,194    5897    6068   211990    4,336
# 5      烏山頭水庫風景區      22,047    1,829    6674   17202   916045   16,278
# 6          曾文水庫      16,403    1,739   10126    8016   925942   12,684
# 7        關子嶺溫泉區           0   74,173   43290   30883        0  165,388
# 8        虎頭埤風景區      15,910   21,707   20777   16840   893862   26,779
# 9        南元休閒農場       2,429    1,721    2629    1521   594945      524
# 10        走馬瀨農場      13,425    7,491   12442    8474  2653380    2,869
# 11      烏樹林休閒園區           0    7,231    5001    2230        0    1,084
# 12         頑皮世界      21,124    2,321   12511   10934  7681858    9,764
# 13       南鯤鯓代天府           0  756,000  453600  302400        0  720,000
# 14        麻豆代天府           0  303,750  182250  121500        0   59,558
# 15     馬沙溝濱海遊憩區         796        0     676     120    93340      698
# 16    國立臺灣歷史博物館       7,976   36,492   29403   15065   808450   21,496
# 17        奇美博物館      29,315   10,933   16635   23613  5363420   19,123
# 18       臺南市美術館      15,036   15,394   15396   15034  2070450   20,064
# 19  臺南山上花園水道博物館      11,880    6,279   11289    6870   776480   10,142
# 20        臺南孔子廟       7,799    3,900    5195    6504   285300    2,779
# 21         祀典武廟           0   19,359    8759   10600        0    7,438
# 22          赤崁樓      17,670    9,986   12513   15143  1201223   10,626
# 23         大天后宮           0   22,125   10010   12115        0    8,501
# 24         安平小鎮      44,949  271,773  137318  179404  2662310   20,592
# 25       南紡購物中心           0  513,878  234870  279008        0        0
# 26         新化老街           0  134,217   49380   84837        0        0
# 27         鹽水老街           0   67,722   24239   43483        0        0
# 28         黃金海岸           0   20,905    8343   12562        0        0
# 29      藍晒圖文創園區           0  342,941  163261  179680        0        0
#
#                            備註
# 1                         門票數
# 2                       停車數概估
# 3                       停車數概估
# 4                         門票數
# 5                         門票數
# 6                         門票數
# 7                      自動車流監視
# 8                         門票數
# 9                         門票數
# 10                        門票數
# 11                        門票數
# 12                        門票數
# 13                       廟方估計
# 14                       廟方估計
# 15                      人工計數器
# 16                        門票數
# 17                        門票數
# 18                   門票數及人工計數
# 19                   門票數及人工計數
# 20                      人工計數器
# 21                      人工計數器
# 22                        門票數
# 23                      人工計數器
# 24  門票數及電信人數推估(自112年1月更新統計方式)
# 25       電信數據人數推估(自112年1月起統計)
# 26       電信數據人數推估(自112年1月起統計)
# 27       電信數據人數推估(自112年1月起統計)
# 28       電信數據人數推估(自112年1月起統計)
# 29       電信數據人數推估(自112年1月起統計)

# %%
# 將門票收、遊客人次假日、由客人次非假日這三列的資料全部的數據轉換為數值(避免其中有些數據是字符串未能察覺而造成無法進行數學運算的情況)
df_new['門票收入'] = pd.to_numeric(df_new['門票收入'])
df_new['遊客人次假日'] = pd.to_numeric(df_new['遊客人次假日'])
df_new['遊客人次非假日'] = pd.to_numeric(df_new['遊客人次非假日'])

# 得知遊客假日與非假日人次差距
df_new['遊客假日與非假日人次差距'] = abs(df_new['遊客人次假日'] - df_new['遊客人次非假日'])

# 列印出處理後的資料
df_new
# Out:
# <ipython-input-33-67a36948c10c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['門票收入'] = pd.to_numeric(df_new['門票收入'])
# <ipython-input-33-67a36948c10c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客人次假日'] = pd.to_numeric(df_new['遊客人次假日'])
# <ipython-input-33-67a36948c10c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客人次非假日'] = pd.to_numeric(df_new['遊客人次非假日'])
# <ipython-input-33-67a36948c10c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客假日與非假日人次差距'] = abs(df_new['遊客人次假日'] - df_new['遊客人次非假日'])
#          觀光遊憩區別 遊客人次有門票_需購票  遊客人次無門票  遊客人次假日  遊客人次非假日     門票收入 上年同月遊客人數  \
# 1          七股鹽山      19,359    7,532   14926    11965   489850   13,215
# 2        北門遊客中心           0   30,549   15337    15212        0   14,892
# 3       井仔腳瓦盤鹽田           0   33,111   15531    17580        0   12,983
# 4      柳營尖山埤渡假村       7,771    4,194    5897     6068   211990    4,336
# 5      烏山頭水庫風景區      22,047    1,829    6674    17202   916045   16,278
# 6          曾文水庫      16,403    1,739   10126     8016   925942   12,684
# 7        關子嶺溫泉區           0   74,173   43290    30883        0  165,388
# 8        虎頭埤風景區      15,910   21,707   20777    16840   893862   26,779
# 9        南元休閒農場       2,429    1,721    2629     1521   594945      524
# 10        走馬瀨農場      13,425    7,491   12442     8474  2653380    2,869
# 11      烏樹林休閒園區           0    7,231    5001     2230        0    1,084
# 12         頑皮世界      21,124    2,321   12511    10934  7681858    9,764
# 13       南鯤鯓代天府           0  756,000  453600   302400        0  720,000
# 14        麻豆代天府           0  303,750  182250   121500        0   59,558
# 15     馬沙溝濱海遊憩區         796        0     676      120    93340      698
# 16    國立臺灣歷史博物館       7,976   36,492   29403    15065   808450   21,496
# 17        奇美博物館      29,315   10,933   16635    23613  5363420   19,123
# 18       臺南市美術館      15,036   15,394   15396    15034  2070450   20,064
# 19  臺南山上花園水道博物館      11,880    6,279   11289     6870   776480   10,142
# 20        臺南孔子廟       7,799    3,900    5195     6504   285300    2,779
# 21         祀典武廟           0   19,359    8759    10600        0    7,438
# 22          赤崁樓      17,670    9,986   12513    15143  1201223   10,626
# 23         大天后宮           0   22,125   10010    12115        0    8,501
# 24         安平小鎮      44,949  271,773  137318   179404  2662310   20,592
# 25       南紡購物中心           0  513,878  234870   279008        0        0
# 26         新化老街           0  134,217   49380    84837        0        0
# 27         鹽水老街           0   67,722   24239    43483        0        0
# 28         黃金海岸           0   20,905    8343    12562        0        0
# 29      藍晒圖文創園區           0  342,941  163261   179680        0        0
#
#                            備註  遊客假日與非假日人次差距
# 1                         門票數          2961
# 2                       停車數概估           125
# 3                       停車數概估          2049
# 4                         門票數           171
# 5                         門票數         10528
# 6                         門票數          2110
# 7                      自動車流監視         12407
# 8                         門票數          3937
# 9                         門票數          1108
# 10                        門票數          3968
# 11                        門票數          2771
# 12                        門票數          1577
# 13                       廟方估計        151200
# 14                       廟方估計         60750
# 15                      人工計數器           556
# 16                        門票數         14338
# 17                        門票數          6978
# 18                   門票數及人工計數           362
# 19                   門票數及人工計數          4419
# 20                      人工計數器          1309
# 21                      人工計數器          1841
# 22                        門票數          2630
# 23                      人工計數器          2105
# 24  門票數及電信人數推估(自112年1月更新統計方式)         42086
# 25       電信數據人數推估(自112年1月起統計)         44138
# 26       電信數據人數推估(自112年1月起統計)         35457
# 27       電信數據人數推估(自112年1月起統計)         19244
# 28       電信數據人數推估(自112年1月起統計)          4219
# 29       電信數據人數推估(自112年1月起統計)         16419

# %%
# 得知遊客平均人次

df_new['遊客平均人次'] = (df_new['遊客人次假日'] + df_new['遊客人次非假日'])/2

# 將遊客平均人次、遊客假日與非假日人次差距這兩列的資料全部的數據轉換為數值(避免其中有些數據是字符串未能察覺而造成無法進行數學運算的情況)
df_new['遊客平均人次'] = pd.to_numeric(df_new['遊客平均人次'])
df_new['遊客假日與非假日人次差距'] = pd.to_numeric(df_new['遊客假日與非假日人次差距'])

# 得知遊客假日與非假日人次變化率以及轉換為百分率
df_new['遊客假日與非假日人次變化率'] = df_new['遊客假日與非假日人次差距'] / df_new['遊客平均人次']
df_new['遊客假日與非假日人次變化百分率'] = df_new['遊客假日與非假日人次變化率'] * 100

# 列印出處理後的資料
df_new
# Out:
# <ipython-input-34-60deaa6a1191>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客平均人次'] = (df_new['遊客人次假日'] + df_new['遊客人次非假日'])/2
# <ipython-input-34-60deaa6a1191>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客平均人次'] = pd.to_numeric(df_new['遊客平均人次'])
# <ipython-input-34-60deaa6a1191>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客假日與非假日人次差距'] = pd.to_numeric(df_new['遊客假日與非假日人次差距'])
# <ipython-input-34-60deaa6a1191>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客假日與非假日人次變化率'] = df_new['遊客假日與非假日人次差距'] / df_new['遊客平均人次']
# <ipython-input-34-60deaa6a1191>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['遊客假日與非假日人次變化百分率'] = df_new['遊客假日與非假日人次變化率'] * 100
#          觀光遊憩區別 遊客人次有門票_需購票  遊客人次無門票  遊客人次假日  遊客人次非假日     門票收入 上年同月遊客人數  \
# 1          七股鹽山      19,359    7,532   14926    11965   489850   13,215
# 2        北門遊客中心           0   30,549   15337    15212        0   14,892
# 3       井仔腳瓦盤鹽田           0   33,111   15531    17580        0   12,983
# 4      柳營尖山埤渡假村       7,771    4,194    5897     6068   211990    4,336
# 5      烏山頭水庫風景區      22,047    1,829    6674    17202   916045   16,278
# 6          曾文水庫      16,403    1,739   10126     8016   925942   12,684
# 7        關子嶺溫泉區           0   74,173   43290    30883        0  165,388
# 8        虎頭埤風景區      15,910   21,707   20777    16840   893862   26,779
# 9        南元休閒農場       2,429    1,721    2629     1521   594945      524
# 10        走馬瀨農場      13,425    7,491   12442     8474  2653380    2,869
# 11      烏樹林休閒園區           0    7,231    5001     2230        0    1,084
# 12         頑皮世界      21,124    2,321   12511    10934  7681858    9,764
# 13       南鯤鯓代天府           0  756,000  453600   302400        0  720,000
# 14        麻豆代天府           0  303,750  182250   121500        0   59,558
# 15     馬沙溝濱海遊憩區         796        0     676      120    93340      698
# 16    國立臺灣歷史博物館       7,976   36,492   29403    15065   808450   21,496
# 17        奇美博物館      29,315   10,933   16635    23613  5363420   19,123
# 18       臺南市美術館      15,036   15,394   15396    15034  2070450   20,064
# 19  臺南山上花園水道博物館      11,880    6,279   11289     6870   776480   10,142
# 20        臺南孔子廟       7,799    3,900    5195     6504   285300    2,779
# 21         祀典武廟           0   19,359    8759    10600        0    7,438
# 22          赤崁樓      17,670    9,986   12513    15143  1201223   10,626
# 23         大天后宮           0   22,125   10010    12115        0    8,501
# 24         安平小鎮      44,949  271,773  137318   179404  2662310   20,592
# 25       南紡購物中心           0  513,878  234870   279008        0        0
# 26         新化老街           0  134,217   49380    84837        0        0
# 27         鹽水老街           0   67,722   24239    43483        0        0
# 28         黃金海岸           0   20,905    8343    12562        0        0
# 29      藍晒圖文創園區           0  342,941  163261   179680        0        0
#
#                            備註  遊客假日與非假日人次差距    遊客平均人次  遊客假日與非假日人次變化率  \
# 1                         門票數          2961   13445.5       0.220222
# 2                       停車數概估           125   15274.5       0.008184
# 3                       停車數概估          2049   16555.5       0.123766
# 4                         門票數           171    5982.5       0.028583
# 5                         門票數         10528   11938.0       0.881890
# 6                         門票數          2110    9071.0       0.232609
# 7                      自動車流監視         12407   37086.5       0.334542
# 8                         門票數          3937   18808.5       0.209320
# 9                         門票數          1108    2075.0       0.533976
# 10                        門票數          3968   10458.0       0.379422
# 11                        門票數          2771    3615.5       0.766422
# 12                        門票數          1577   11722.5       0.134528
# 13                       廟方估計        151200  378000.0       0.400000
# 14                       廟方估計         60750  151875.0       0.400000
# 15                      人工計數器           556     398.0       1.396985
# 16                        門票數         14338   22234.0       0.644868
# 17                        門票數          6978   20124.0       0.346750
# 18                   門票數及人工計數           362   15215.0       0.023792
# 19                   門票數及人工計數          4419    9079.5       0.486701
# 20                      人工計數器          1309    5849.5       0.223780
# 21                      人工計數器          1841    9679.5       0.190196
# 22                        門票數          2630   13828.0       0.190194
# 23                      人工計數器          2105   11062.5       0.190282
# 24  門票數及電信人數推估(自112年1月更新統計方式)         42086  158361.0       0.265760
# 25       電信數據人數推估(自112年1月起統計)         44138  256939.0       0.171784
# 26       電信數據人數推估(自112年1月起統計)         35457   67108.5       0.528353
# 27       電信數據人數推估(自112年1月起統計)         19244   33861.0       0.568323
# 28       電信數據人數推估(自112年1月起統計)          4219   10452.5       0.403635
# 29       電信數據人數推估(自112年1月起統計)         16419  171470.5       0.095754
#
#     遊客假日與非假日人次變化百分率
# 1         22.022238
# 2          0.818357
# 3         12.376552
# 4          2.858337
# 5         88.188976
# 6         23.260941
# 7         33.454222
# 8         20.932025
# 9         53.397590
# 10        37.942245
# 11        76.642235
# 12        13.452762
# 13        40.000000
# 14        40.000000
# 15       139.698492
# 16        64.486822
# 17        34.675015
# 18         2.379231
# 19        48.670081
# 20        22.377981
# 21        19.019577
# 22        19.019381
# 23        19.028249
# 24        26.575988
# 25        17.178396
# 26        52.835334
# 27        56.832344
# 28        40.363549
# 29         9.575408

# %%
# 將遊客假日與非假日人次變化百分率最大的值取出並儲存在max_percentage這個變數中
max_percentage = df_new['遊客假日與非假日人次變化百分率'].max()

# 將遊客假日與非假日人次變化百分率最大的值所對應的資料儲存在max_percentage這個變數中
max_percentage_row = df_new[df_new['遊客假日與非假日人次變化百分率'] == max_percentage]

# 列印出需要提取的資料
max_percentage_row
# Out:
#       觀光遊憩區別 遊客人次有門票_需購票 遊客人次無門票  遊客人次假日  遊客人次非假日   門票收入 上年同月遊客人數     備註  \
# 15  馬沙溝濱海遊憩區         796       0     676      120  93340      698  人工計數器
#
#     遊客假日與非假日人次差距  遊客平均人次  遊客假日與非假日人次變化率  遊客假日與非假日人次變化百分率
# 15           556   398.0       1.396985       139.698492

# %%
# 將遊客假日與非假日人次變化百分率最大的觀光遊憩景點提取出來並儲存在result變數中
result = max_percentage_row.loc[15,'觀光遊憩區別']

rounded_ratio = round(max_percentage, 2)

# 列印出提取的資料
print('遊客假日與非假日人次變化的景點:',result,'，變化百分率為: {:.2f}%'.format(rounded_ratio))
# Out:
# 遊客假日與非假日人次變化的景點: 馬沙溝濱海遊憩區 ，變化百分率為: 139.70%

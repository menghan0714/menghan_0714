# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1 = pd.read_csv('/content/drive/My Drive/practice/GDP3.csv')
#data1 = pd.read_csv('/content/drive/My Drive/practice/population-female.csv')

# %%
data1.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.112502e+10  2.161623e+10  2.350628e+10  2.804836e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.044764e+10  1.117321e+10  1.199053e+10  1.272769e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2013          2014          2015  \
# ...

# %%
tempset = data1[data1['Country Code']=='AFG']

tempset.fillna(0,inplace = True)

tempset = tempset.iloc[:, 4:]

tempset = tempset.melt(var_name='YEAR', value_name='GDP')

tempset
# Out:
# <ipython-input-8-dba4695a149a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempset.fillna(0,inplace = True)
#     YEAR           GDP
# 0   1960  5.377778e+08
# 1   1961  5.488889e+08
# 2   1962  5.466667e+08
# 3   1963  7.511112e+08
# 4   1964  8.000000e+08
# ..   ...           ...
# 58  2018  1.841886e+10
# 59  2019  1.890450e+10
# 60  2020  2.014345e+10
# 61  2021  1.458314e+10
# 62  2022  0.000000e+00
#
# [63 rows x 2 columns]

# %%
import plotly.express as px

fig = px.line(tempset, x="YEAR", y="GDP", title='AFW GDP 1960 - 2022')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
